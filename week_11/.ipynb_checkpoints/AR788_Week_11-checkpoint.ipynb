# %% [markdown]
# <a href="https://colab.research.google.com/github/maipatana/AR788/blob/master/week_11/AR788_Week_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
_URL = 'https://ar788.s3-ap-southeast-1.amazonaws.com/Dataset100.zip'

path_to_zip = tf.keras.utils.get_file('Dataset100.zip',
                                      origin=_URL,
                                      extract=True,
                                      archive_format='zip')

data_dir = os.path.join(os.path.dirname(path_to_zip), 'Dataset100/')

# %%
print(data_dir)
print([i for i in os.listdir(data_dir)])
# Out:
# /root/.keras/datasets/Dataset100/
# ['rat', 'mue7', 'niwet', '.DS_Store', 'siri']

# %%
batch_size = 32
img_height = 100
img_width = 100

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 430 files belonging to 4 classes.
# Using 344 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 430 files belonging to 4 classes.
# Using 86 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['mue7', 'niwet', 'rat', 'siri']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 100, 100, 3)
# (32,)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 4

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_6 (Rescaling)      (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 50, 50, 16)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 40000)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                1280032
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 1,280,612
# Trainable params: 1,280,612
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 2s 142ms/step - loss: 2.4015 - accuracy: 0.3343 - val_loss: 1.2260 - val_accuracy: 0.4070
# Epoch 2/10
# 11/11 [==============================] - 1s 132ms/step - loss: 1.0572 - accuracy: 0.5581 - val_loss: 0.7773 - val_accuracy: 0.8372
# Epoch 3/10
# 11/11 [==============================] - 1s 133ms/step - loss: 0.6179 - accuracy: 0.8576 - val_loss: 0.4747 - val_accuracy: 0.8953
# Epoch 4/10
# 11/11 [==============================] - 1s 133ms/step - loss: 0.3636 - accuracy: 0.9157 - val_loss: 0.4114 - val_accuracy: 0.8953
# Epoch 5/10
# 11/11 [==============================] - 1s 136ms/step - loss: 0.2481 - accuracy: 0.9273 - val_loss: 0.2854 - val_accuracy: 0.9419
# Epoch 6/10
# 11/11 [==============================] - 1s 135ms/step - loss: 0.1701 - accuracy: 0.9506 - val_loss: 0.1999 - val_accuracy: 0.9767
# Epoch 7/10
# 11/11 [==============================] - 1s 135ms/step - loss: 0.0994 - accuracy: 0.9913 - val_loss: 0.1561 - val_accuracy: 0.9884
# Epoch 8/10
# 11/11 [==============================] - 2s 138ms/step - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9651
# Epoch 9/10
# 11/11 [==============================] - 1s 136ms/step - loss: 0.0510 - accuracy: 0.9971 - val_loss: 0.1748 - val_accuracy: 0.9419
# Epoch 10/10
# 11/11 [==============================] - 1s 135ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9651

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
